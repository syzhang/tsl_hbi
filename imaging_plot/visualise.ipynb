# %% [markdown]
# ### visualise imaging results

# %%
import numpy as np
import nilearn.plotting

# %% [markdown]
# #### all pain

# %%
img = '../../TSL_output/2ndLevel_masked_FWE005/2ndLevel/con_0001/spmT_0001_thr.nii'
ttl = 'all_pain (FWE p<0.05)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=4, vmax=10, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);
# Out:
# -----------------------------------------------------------------
# ValueError                      Traceback (most recent call last)
# <ipython-input-3-d526d0704660> in <module>
# ----> 1 g = nilearn.plotting.plot_stat_map(
#       2     img, title=ttl,
#       3     threshold=4, vmax=10, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
#       4     colorbar=True);
#
# ~/.local/lib/python3.8/site-packages/nilearn/plotting/img_plotting.py in plot_stat_map(stat_map_img, bg_img, cut_coords, output_file, display_mode, colorbar, figure, axes, title, threshold, annotate, draw_cross, black_bg, cmap, symmetric_cbar, dim, vmax, resampling_interpolation, **kwargs)
#    1156                                                     black_bg=black_bg)
#    1157
# -> 1158     stat_map_img = _utils.check_niimg_3d(stat_map_img, dtype='auto')
#    1159
#    1160     cbar_vmin, cbar_vmax, vmin, vmax = _get_colorbar_and_data_ranges(
#
# ...

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=4, vmax=10, display_mode='x', cut_coords=(-45, -30, -15, 0),
    colorbar=True);

# %%
g.savefig('./figs/all_pain_x.pdf')

# %%
img = '../../TSL_output/2ndLevel_masked_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
ttl = 'all_pain (p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=4, vmax=10, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
all_pain_x = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=4, vmax=10, display_mode='x', cut_coords=(-45, -30, -15, 0),
    colorbar=True);

# %% [markdown]
# #### high>low pain

# %%
img = '../../TSL_output/2ndLevel_masked_FDR0001/2ndLevel/con_0004/spmT_0001_thr.nii'
ttl = 'high>low pain (p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-45, -30, -5, 5),
    colorbar=True);

# %%
g.savefig('./figs/high_minus_low_x.pdf')

# %% [markdown]
# ### io_jump_freq probabilities

# %%
img = '../../../TSL_output/2ndLevel_io_jump_freq_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
ttl = 'IO Jump frequency probability p1 (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-45, -30, -5, 5),
    colorbar=True);

# %% [markdown]
# #### used for imaging

# %%
img = '../../../TSL_output/2ndLevel_io_jump_freq_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
ttl = 'IO (jump frequency) p(h) (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g.savefig('./figs/io_jump_freq_ph_z.pdf')

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-25, -5, 5, 10),
    colorbar=True);

# %%
g.savefig('./figs/io_jump_freq_ph_x.pdf')

# %% [markdown]
# ### io_jump_freq surprise

# %%
# img = '../../../TSL_output/2ndLevel_io_jump_freq_surp_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
img = '../../../TSL_output/2ndLevel_io_jump_freq_surp_FDR0001/2ndLevel/con_0001/spmT_0001.nii'
ttl = 'IO (Jump frequency) - surprise (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-45, -30, -5, 5),
    colorbar=True);

# %% [markdown]
# #### used for imaging

# %%
# img = '../../../TSL_output/2ndLevel_io_jump_freq_surp_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
img = '../../../TSL_output/2ndLevel_io_jump_freq_surp_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
ttl = 'IO (jump frequency) surprise(h) (not thresholded)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-8, -5, 0, 20, 45),
    colorbar=True);

# %%
g.savefig('./figs/io_jump_freq_sh_z.pdf')

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-30, -5, 0, 5),
    colorbar=True);

# %%
g.savefig('./figs/io_jump_freq_sh_x.pdf')

# %% [markdown]
# ### RW probabilities

# %%
img = '../../../TSL_output/2ndLevel_rw_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
ttl = 'RW probability - p(l) (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-45, -30, -5, 5),
    colorbar=True);

# %% [markdown]
# #### used for imaging

# %%
img = '../../../TSL_output/2ndLevel_rw_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
ttl = 'RW p(h) (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g.savefig('./figs/rw_z.pdf')

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-30, -5, 0, 5),
    colorbar=True);

# %%
g.savefig('./figs/rw_x.pdf')

# %% [markdown]
# ### RW surprise

# %%
# img = '../../../TSL_output/2ndLevel_rw_surp_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
img = '../../../TSL_output/2ndLevel_rw_surp_FDR0001/2ndLevel/con_0001/spmT_0001.nii'
ttl = 'RW surprise(l) (not thresholded)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=(-45, -30, -5, 5),
    colorbar=True);

# %% [markdown]
# #### used for imaging

# %%
# img = '../../../TSL_output/2ndLevel_rw_surp_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
img = '../../../TSL_output/2ndLevel_rw_surp_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
ttl = 'RW surprise(h) (not thresholded)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-8, -5, 0, 5, 15),
    colorbar=True);

# %%
g.savefig('./figs/rw_sh_z.pdf')

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g.savefig('./figs/rw_sh_x.pdf')

# %% [markdown]
# #### io jump freq pe

# %%
img = '../../../TSL_output/2ndLevel_io_jump_freq_pe_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
ttl = 'IO (Jump frequency) - KL Divergence (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15, 25),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=2.5, vmax=8, display_mode='y', cut_coords=(-40, -35, -25, -15),
    colorbar=True);

# %%
img = '../../../TSL_output/2ndLevel_io_jump_freq_pe_FDR0001/2ndLevel/con_0001/spmT_0001.nii'
ttl = 'IO (Jump frequency) - KL Divergence (not thresholded)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3., vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %% [markdown]
# #### rw pe

# %%
img = '../../../TSL_output/2ndLevel_rw_pe_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
ttl = 'RW - PE (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=2.5, vmax=8, display_mode='y', cut_coords=(-40, -35, -25, -15),
    colorbar=True);

# %%
img = '../../../TSL_output/2ndLevel_rw_pe_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
ttl = 'RW - PE (not thresholded)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=2.5, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=2.5, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %% [markdown]
# #### io jump freq sd

# %%
img = '../../../TSL_output/2ndLevel_io_jump_freq_sd_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
ttl = 'IO (Jump frequency) - posterior SD (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=2.5, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %%
img = '../../../TSL_output/2ndLevel_io_jump_freq_sd_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
ttl = 'IO (Jump frequency) -  posterior SD (not thresholded)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
    colorbar=True);

# %% [markdown]
# #### mean param fmc fitting

# %%
img = '../../../TSL_output/2ndLevel_io_jf_prob_mean_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
# img = '../../../TSL_output/2ndLevel_io_jf_prob_mean_FDR0001/2ndLevel/con_0002/con_0001.nii'
# img = '../../../TSL_output/2ndLevel_io_jf_prob_mean_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
ttl = 'IO (Jump frequency) -  posterior mean (FDR p<0.001)'

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=threshold, vmax=8, display_mode='x', 
    cut_coords=( -30, -5, 0, 5),
    colorbar=True);

# %%
g = nilearn.plotting.plot_stat_map(
    img, title=ttl,
    threshold=threshold, vmax=8, display_mode='z', cut_coords=(-22, -19, -10, -7, 0, 12),
    colorbar=True);

# %%
# ## for reference - fdr 0.05 on unthresholded spmT_0001 using nilearn threshold
# clean_map, threshold = threshold_stats_img(
#     z_map, alpha=.05, height_control='fdr', cluster_threshold=0)
# nilearn.plotting.plot_stat_map(clean_map, threshold=3, vmax=8,
#               display_mode='z', cut_coords=(-10, -8, -5, 0, 5, 15), 
#               title=ttl+'(fdr=0.05), clusters > 10 voxels')

# %%
# ## for reference - height_threshold=0.05, use_fwe_correction=False in 2nd level nipype (equivalent to above)
# g = nilearn.plotting.plot_stat_map(
#     img, title=ttl,
#     threshold=3, vmax=8, display_mode='z', cut_coords=(-15, -5, 0, 5, 15),
#     colorbar=True);

# %%
# from nilearn.glm import threshold_stats_img
# z_map = img
# _, threshold = threshold_stats_img(
#     z_map, alpha=.05, height_control='bonferroni')
# print('Bonferroni-corrected, p<0.05 threshold: %.3f' % threshold)
# nilearn.plotting.plot_stat_map(z_map, threshold=threshold,
#               display_mode='z', cut_coords=(-10, -8, -5, 0, 5, 15), black_bg=True,
#               title=ttl+'(p<0.05, corrected)')

# %%
# clean_map, threshold = threshold_stats_img(
#     z_map, alpha=.001, height_control='fpr', cluster_threshold=10)
# nilearn.plotting.plot_stat_map(clean_map, threshold=3, vmax=7,
#               display_mode='z', cut_coords=(-10, -8, -5, 0, 5, 15), 
#               title=ttl+'(fdr=0.05), clusters > 10 voxels')

# %% [markdown]
# #### plot posterior mean

# %%
img = '../../../TSL_output/2ndLevel_io_jf_prob_mean_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
ttl = 'IO (Jump frequency) -  posterior mean '

# %%
from nilearn.glm import threshold_stats_img
z_map = img
clean_map, threshold = threshold_stats_img(
#     z_map, alpha=.001, height_control='fdr', cluster_threshold=10)
    z_map, alpha=.001, height_control='fpr', cluster_threshold=10)
peak_z = np.unique(peaks['Z'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='z', cut_coords=(peak_z)) 
#               title=ttl+'(fdr=0.001), clusters>10 voxels')
# g.savefig('./figs/io_jump_freq_ph_z.pdf')

# %%
peak_x = np.unique(peaks['X'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='x', cut_coords=(peak_x)) 
#               title=ttl+'(fdr=0.001), clusters>10 voxels')
g.savefig('./figs/io_jump_freq_ph_x.pdf')

# %%
peak_y = np.unique(peaks['Y'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='y', cut_coords=(peak_y[:-2]))
#               title=ttl+'(fdr=0.001), clusters > 10 voxels')
g.savefig('./figs/io_jump_freq_ph_y.pdf')

# %%
threshold
# Out:
# 3.2905267314918945

# %%
from nilearn.reporting import get_clusters_table
table = get_clusters_table(clean_map, stat_threshold=threshold,
                           cluster_threshold=10)
table[['X','Y','Z']] = table[['X','Y','Z']].astype(int)
table[['Peak Stat']] = table[['Peak Stat']].round(3)

# %%
table
# Out:
#    Cluster ID   X   Y   Z  Peak Stat Cluster Size (mm3)
# 0           1  25   9  -6      7.285               8967
# 1          1a  37   6  -9      4.541
# 2          1b   6  13   2      4.444
# 3          1c  28 -10  -3      3.945
# 4           2 -24 -55 -19      6.980               9830
# 5          2a -19 -67 -19      6.484
# 6          2b  -2 -60  -9      5.332
# 7          2c  -7 -60 -22      5.315
# 8           3 -24   6  -6      5.226               2102
# 9          3a -24  16  -9      4.836
# 10         3b -10  11   0      4.168
# 11          4 -46   0   5      4.907               1922
# 12         4a -46  13  -6      4.681
# 13          5 -24  -5  11      4.871               2336
# 14         5a -14 -12  11      3.976
# 15          6   9  35  11      4.418               2066
# 16         6a -12  40   5      4.338
# 17         6b -17  45  15      3.852
# 18          7  49  23  -9      4.282                682

# %%
peaks = table[table['Cluster Size (mm3)'].astype(str).apply(lambda x: len(x))>0]

# %%
print(table.to_latex())
# Out:
# \begin{tabular}{llrrrrl}
# \toprule
# {} & Cluster ID &   X &   Y &   Z &  Peak Stat & Cluster Size (mm3) \\
# \midrule
# 0  &          1 &  25 &   9 &  -6 &      7.285 &               8967 \\
# 1  &         1a &  37 &   6 &  -9 &      4.541 &                    \\
# 2  &         1b &   6 &  13 &   2 &      4.444 &                    \\
# 3  &         1c &  28 & -10 &  -3 &      3.945 &                    \\
# 4  &          2 & -24 & -55 & -19 &      6.980 &               9830 \\
# 5  &         2a & -19 & -67 & -19 &      6.484 &                    \\
# 6  &         2b &  -2 & -60 &  -9 &      5.332 &                    \\
# 7  &         2c &  -7 & -60 & -22 &      5.315 &                    \\
# 8  &          3 & -24 &   6 &  -6 &      5.226 &               2102 \\
# 9  &         3a & -24 &  16 &  -9 &      4.836 &                    \\
# 10 &         3b & -10 &  11 &   0 &      4.168 &                    \\
# 11 &          4 & -46 &   0 &   5 &      4.907 &               1922 \\
# ...

# %%
img = '../../../TSL_output/2ndLevel_io_jf_prob_mean_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
ttl = 'IO (Jump frequency) -  posterior mean '

# %%
from nilearn.reporting import get_clusters_table
table = get_clusters_table(clean_map, stat_threshold=threshold,
                           cluster_threshold=10)
table[['X','Y','Z']] = table[['X','Y','Z']].astype(int)
table[['Peak Stat']] = table[['Peak Stat']].round(3)

# %%
peaks = table[table['Cluster Size (mm3)'].astype(str).apply(lambda x: len(x))>0]

# %%
from nilearn.glm import threshold_stats_img
z_map = img
clean_map, threshold = threshold_stats_img(
#     z_map, alpha=.001, height_control='fdr', cluster_threshold=10)
    z_map, alpha=.001, height_control='fpr', cluster_threshold=10)
peak_z = np.unique(peaks['Z'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='z', cut_coords=(peak_z)) 
#               title=ttl+'(fdr=0.001), clusters>10 voxels')
g.savefig('./figs/io_jump_freq_pl_z.pdf')

# %%
peak_x = np.unique(peaks['X'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='x', cut_coords=(peak_x)) 
#               title=ttl+'(fdr=0.001), clusters>10 voxels')
g.savefig('./figs/io_jump_freq_pl_x.pdf')

# %%
peak_y = np.unique(peaks['Y'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='y', cut_coords=(peak_y[:-2]))
#               title=ttl+'(fdr=0.001), clusters > 10 voxels')
g.savefig('./figs/io_jump_freq_pl_y.pdf')

# %%
print(table.to_latex())
# Out:
# \begin{tabular}{llrrrrl}
# \toprule
# {} & Cluster ID &   X &   Y &   Z &  Peak Stat & Cluster Size (mm3) \\
# \midrule
# 0  &          1 &   9 & -41 &  58 &      7.459 &              30011 \\
# 1  &         1a & -10 & -48 &  61 &      6.741 &                    \\
# 2  &         1b &  13 & -34 &  61 &      6.517 &                    \\
# 3  &         1c & -29 & -34 &  68 &      6.410 &                    \\
# 4  &          2 & -41 & -34 &  18 &      6.237 &               3791 \\
# 5  &         2a & -53 & -22 &   2 &      4.599 &                    \\
# 6  &         2b & -62 & -14 &   5 &      3.556 &                    \\
# 7  &          3 & -48 & -74 &  11 &      5.930 &               3234 \\
# 8  &         3a & -55 & -70 &  -6 &      4.503 &                    \\
# 9  &         3b & -43 & -89 &  11 &      3.934 &                    \\
# 10 &          4 &  49 & -29 &   8 &      5.245 &               1671 \\
# 11 &         4a &  37 & -26 &  15 &      5.042 &                    \\
# ...

# %% [markdown]
# #### io freq jump surprise (local mean params)

# %%
img = '../../../TSL_output/2ndLevel_io_jf_surprise_mean_surp_FDR0001/2ndLevel/con_0002/spmT_0001_thr.nii'
# img = '../../../TSL_output/2ndLevel_io_jf_surprise_mean_surp_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
z_map = img
ttl = 'IO (Jump frequency) -  entropy surprise'

# %%
from nilearn.glm import threshold_stats_img
# clean_map, threshold = threshold_stats_img(
#     z_map, alpha=.001, height_control='fdr', cluster_threshold=0)
clean_map, threshold = threshold_stats_img(
    z_map, alpha=.001, height_control='fpr', cluster_threshold=10)
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='ortho', draw_cross=False)
#               title=ttl+'(unthresholded p=0.001)')
g.savefig('./figs/io_jump_freq_sh_orth.pdf')

# %%
from nilearn.reporting import get_clusters_table
table = get_clusters_table(clean_map, stat_threshold=threshold,
                           cluster_threshold=10)
# print(table)
table[['X','Y','Z']] = table[['X','Y','Z']].astype(int)
table[['Peak Stat']] = table[['Peak Stat']].round(3)

# %%
table
# Out:
#   Cluster ID   X   Y   Z  Peak Stat Cluster Size (mm3)
# 0          1   9 -26  46      6.084              14808
# 1         1a -14 -34  49      5.585
# 2         1b  -2 -24  46      5.407
# 3         1c   0 -36  52      5.302

# %%
print(table.to_latex())
# Out:
# \begin{tabular}{llrrrrl}
# \toprule
# {} & Cluster ID &   X &   Y &   Z &  Peak Stat & Cluster Size (mm3) \\
# \midrule
# 0 &          1 &   9 & -26 &  46 &      6.084 &              14808 \\
# 1 &         1a & -14 & -34 &  49 &      5.585 &                    \\
# 2 &         1b &  -2 & -24 &  46 &      5.407 &                    \\
# 3 &         1c &   0 & -36 &  52 &      5.302 &                    \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### p(L) surprise

# %%
img = '../../../TSL_output/2ndLevel_io_jf_surprise_mean_surp_FDR0001/2ndLevel/con_0001/spmT_0001_thr.nii'
# img = '../../../TSL_output/2ndLevel_io_jf_surprise_mean_surp_FDR0001/2ndLevel/con_0002/spmT_0001.nii'
z_map = img
ttl = 'IO (Jump frequency) -  entropy surprise'

# %%
from nilearn.glm import threshold_stats_img
# clean_map, threshold = threshold_stats_img(
#     z_map, alpha=.001, height_control='fdr', cluster_threshold=0)
clean_map, threshold = threshold_stats_img(
    z_map, alpha=.001, height_control='fpr', cluster_threshold=10)
peak_x = np.unique(peaks['X'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='x', cut_coords=(peak_x), draw_cross=False)
#               title=ttl+'(unthresholded p=0.001)')
g.savefig('./figs/io_jump_freq_sl_x.pdf')

# %%
peak_y = np.unique(peaks['Y'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='y', cut_coords=(peak_y), draw_cross=False)
#               title=ttl+'(unthresholded p=0.001)')
g.savefig('./figs/io_jump_freq_sl_y.pdf')

# %%
peak_z = np.unique(peaks['Z'])
g = nilearn.plotting.plot_stat_map(clean_map, threshold=threshold, vmax=7,
              display_mode='z', cut_coords=(peak_z), draw_cross=False)
#               title=ttl+'(unthresholded p=0.001)')
g.savefig('./figs/io_jump_freq_sl_z.pdf')

# %%
from nilearn.reporting import get_clusters_table
table = get_clusters_table(clean_map, stat_threshold=threshold,
                           cluster_threshold=10)
# print(table)
table[['X','Y','Z']] = table[['X','Y','Z']].astype(int)
table[['Peak Stat']] = table[['Peak Stat']].round(3)

# %%
table
# Out:
#    Cluster ID   X   Y   Z  Peak Stat Cluster Size (mm3)
# 0           1 -48   4  33      7.154              10549
# 1          1a -26  -5  49      5.926
# 2          1b -43  -2  52      4.948
# 3          1c -60   6  18      4.931
# 4           2  57   9  24      6.453               2462
# 5          2a  54   4  36      4.256
# 6          2b  49   4  21      4.234
# 7           3 -60 -17  33      4.897               1078
# 8           4  40 -48  49      4.849               4061
# 9          4a  30 -65  61      4.690
# 10         4b  42 -53  61      4.463
# 11         4c  45 -46  58      4.333
# 12          5 -43 -41  40      4.838               2767
# 13         5a -36 -50  52      4.827
# 14          6  -7   1  61      4.601                988
# 15         6a   4   0  65      3.924
# 16          7  33  -2  65      4.592               1060

# %%
peaks = table[table['Cluster Size (mm3)'].astype(str).apply(lambda x: len(x))>0]

# %%
print(table.to_latex())
# Out:
# \begin{tabular}{llrrrrl}
# \toprule
# {} & Cluster ID &   X &   Y &   Z &  Peak Stat & Cluster Size (mm3) \\
# \midrule
# 0  &          1 & -48 &   4 &  33 &      7.154 &              10549 \\
# 1  &         1a & -26 &  -5 &  49 &      5.926 &                    \\
# 2  &         1b & -43 &  -2 &  52 &      4.948 &                    \\
# 3  &         1c & -60 &   6 &  18 &      4.931 &                    \\
# 4  &          2 &  57 &   9 &  24 &      6.453 &               2462 \\
# 5  &         2a &  54 &   4 &  36 &      4.256 &                    \\
# 6  &         2b &  49 &   4 &  21 &      4.234 &                    \\
# 7  &          3 & -60 & -17 &  33 &      4.897 &               1078 \\
# 8  &          4 &  40 & -48 &  49 &      4.849 &               4061 \\
# 9  &         4a &  30 & -65 &  61 &      4.690 &                    \\
# 10 &         4b &  42 & -53 &  61 &      4.463 &                    \\
# 11 &         4c &  45 & -46 &  58 &      4.333 &                    \\
# ...
